# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import impute, preprocessing, decomposition
from scipy import stats

pd.set_option("display.max_columns", None)

# %%
df_fifa = pd.read_csv("data/players_22.csv")
df_fifa.head(2)
# Out:
# /var/folders/94/cdr1n80n7fxcscjbjwxbbhr54jjq06/T/ipykernel_49346/53088129.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fifa = pd.read_csv("data/players_22.csv")
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
#
#        short_name                       long_name player_positions  overall  \
# 0        L. Messi  Lionel Andrés Messi Cuccittini       RW, ST, CF       93
# 1  R. Lewandowski              Robert Lewandowski               ST       92
#
#    potential    value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 0         93   78000000.0  320000.0   34  1987-06-24        170         72
# 1         92  119500000.0  270000.0   32  1988-08-21        185         81
#
#    club_team_id            club_name           league_name  league_level  \
# ...

# %%
df_fifa.shape
# Out:
# (19239, 110)

# %%
df_fifa.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   19239.000000  19239.000000  19239.000000  1.916500e+04   19178.000000
# mean   231468.086959     65.772182     71.079370  2.850452e+06    9017.989363
# std     27039.717497      6.880232      6.086213  7.613700e+06   19470.176724
# min        41.000000     47.000000     49.000000  9.000000e+03     500.000000
# 25%    214413.500000     61.000000     67.000000  4.750000e+05    1000.000000
# 50%    236543.000000     66.000000     71.000000  9.750000e+05    3000.000000
# 75%    253532.500000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     93.000000     95.000000  1.940000e+08  350000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  19239.000000  19239.000000  19239.000000   19178.000000  19178.000000
# mean      25.210822    181.299704     74.943032   50580.498123      1.354364
# ...

# %%
df_fifa_num = df_fifa.select_dtypes([np.number])
correlation_matrix = df_fifa_num.corr()

correlation_matrix
# Out:
#                              sofifa_id   overall  potential  value_eur  \
# sofifa_id                     1.000000 -0.491523   0.037576  -0.128102
# overall                      -0.491523  1.000000   0.644275   0.554684
# potential                     0.037576  0.644275   1.000000   0.527738
# value_eur                    -0.128102  0.554684   0.527738   1.000000
# wage_eur                     -0.253044  0.601764   0.497611   0.823527
# age                          -0.781023  0.459451  -0.264142   0.042886
# height_cm                    -0.100362  0.042787   0.004403   0.010291
# weight_kg                    -0.207461  0.150324  -0.016912   0.035188
# club_team_id                  0.110305 -0.226640  -0.330928  -0.191468
# league_level                 -0.036769 -0.179032  -0.153075  -0.117917
# club_jersey_number            0.183841 -0.186166   0.009784  -0.067670
# club_contract_valid_until     0.128058  0.184987   0.345188   0.217051
# ...

# %%
# %matplotlib inline
plt.figure()
correlation_matrix = correlation_matrix.astype(float)
sns.heatmap(correlation_matrix, cmap="coolwarm", annot=False, fmt=".2f", linewidths=.5)
plt.title("Correlation matrix")
plt.show()

# %%
df_fifa_num.isnull().sum()
# Out:
# sofifa_id                          0
# overall                            0
# potential                          0
# value_eur                         74
# wage_eur                          61
# age                                0
# height_cm                          0
# weight_kg                          0
# club_team_id                      61
# league_level                      61
# club_jersey_number                61
# club_contract_valid_until         61
# nationality_id                     0
# nation_team_id                 18480
# nation_jersey_number           18480
# weak_foot                          0
# skill_moves                        0
# international_reputation           0
# release_clause_eur              1176
# pace                            2132
# shooting                        2132
# passing                         2132
# dribbling                       2132
# defending                       2132
# physic                          2132
# ...

# %%
imputer = impute.SimpleImputer(strategy="mean")
df_fifa_num = pd.DataFrame(imputer.fit_transform(df_fifa_num), columns=df_fifa_num.columns)
df_fifa_num.isnull().sum()
# Out:
# sofifa_id                      0
# overall                        0
# potential                      0
# value_eur                      0
# wage_eur                       0
# age                            0
# height_cm                      0
# weight_kg                      0
# club_team_id                   0
# league_level                   0
# club_jersey_number             0
# club_contract_valid_until      0
# nationality_id                 0
# nation_team_id                 0
# nation_jersey_number           0
# weak_foot                      0
# skill_moves                    0
# international_reputation       0
# release_clause_eur             0
# pace                           0
# shooting                       0
# passing                        0
# dribbling                      0
# defending                      0
# physic                         0
# attacking_crossing             0
# attacking_finishing            0
# attacking_heading_accuracy     0
# ...

# %%
scaler = preprocessing.StandardScaler()
df_fifa_normalized = scaler.fit_transform(df_fifa_num)

pca = decomposition.PCA()
pca.fit(df_fifa_normalized)

cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# %matplotlib inline
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker="o")
plt.xlabel("Number of components")
plt.ylabel("Cumulative explained variance")
plt.title("Explained variance vs Number of components")
plt.show()

# %%
variance_threshold = 0.8
pca_n = np.argmax(cumulative_variance > variance_threshold) + 1

print(f"Number of components to explain {variance_threshold} variance: {pca_n}")
# Out:
# Number of components to explain 0.8 variance: 10

# %%
pca = decomposition.PCA(n_components=pca_n)
main_components = pca.fit_transform(df_fifa_normalized)

# %%
explained_variance_ratio = pca.explained_variance_ratio_
explained_variance_ratio
# Out:
# array([0.35987355, 0.12243569, 0.1141741 , 0.05223797, 0.04113113,
#        0.03103841, 0.0268517 , 0.0224194 , 0.017692  , 0.01716971])

# %%
num_components = main_components.shape[1]
column_names = [f"PC{i}" for i in range(1, num_components + 1)]
pca_df = pd.DataFrame(main_components, columns=column_names)
pca_df.head()
# Out:
#          PC1       PC2        PC3        PC4        PC5       PC6        PC7  \
# 0  14.210223 -5.162168  15.409327  -7.898280  -6.241177 -1.627047  10.319873
# 1  13.364274 -1.849448  17.164792  -7.800535 -10.648250 -1.105334  11.946598
# 2  12.759237 -2.929506  14.784395  -1.972866  -5.180725  1.450131   7.763808
# 3  14.604426 -5.226395  16.436686 -12.085066  -9.631826 -1.891718  12.606835
# 4  14.900056 -1.102365  18.030189 -11.889059  -9.217311 -3.474394  11.884177
#
#         PC8       PC9      PC10
# 0  6.941054 -1.297256  0.111136
# 1  7.246309 -2.996562  0.391341
# 2  6.636183 -0.672214  1.554317
# 3  7.857945 -3.311925  0.134067
# 4  7.520638 -3.072125  1.472745

# %%
plt.figure(figsize=(15, 8))
for index, col in enumerate(pca_df.columns[:10]):
    plt.subplot(2, 5, index + 1)
    sns.histplot(pca_df[col], kde=True, bins=20)
    plt.title(f"{col} histogram")
plt.tight_layout()
plt.show()

# %%
for colum in pca_df.columns:
    stat, p_value = stats.shapiro(pca_df[colum])
    print(f"Shapiro-Wilk test for {colum}: {p_value}")
    if p_value < 0.05:
        print(f"{colum} is not normally distributed")
    else:
        print(f"{colum} is normally distributed")
# Out:
# Shapiro-Wilk test for PC1: 2.4673371650762197e-73
# PC1 is not normally distributed
# Shapiro-Wilk test for PC2: 5.440130885327867e-44
# PC2 is not normally distributed
# Shapiro-Wilk test for PC3: 1.7835000921100965e-62
# PC3 is not normally distributed
# Shapiro-Wilk test for PC4: 2.1453704354600944e-50
# PC4 is not normally distributed
# Shapiro-Wilk test for PC5: 7.747589352164573e-47
# PC5 is not normally distributed
# Shapiro-Wilk test for PC6: 1.572080573999645e-17
# PC6 is not normally distributed
# Shapiro-Wilk test for PC7: 3.1102027786294517e-65
# PC7 is not normally distributed
# Shapiro-Wilk test for PC8: 9.172787296929315e-53
# PC8 is not normally distributed
# Shapiro-Wilk test for PC9: 2.428940674378518e-59
# PC9 is not normally distributed
# Shapiro-Wilk test for PC10: 6.21494470017564e-125
# PC10 is not normally distributed
# ...
