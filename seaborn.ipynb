# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = np.random.randint(low=1,
                         high=100,
                         size=(10, 10))
data
# Out:
# array([[54, 54, 81, 74, 97, 72, 79, 64, 23, 66],
#        [80, 31, 44, 91, 44, 67,  5, 80,  3, 14],
#        [43, 40, 56, 19, 85, 33, 23, 99, 10, 47],
#        [ 3, 49, 14, 69, 26, 56, 57, 44, 81, 66],
#        [16, 90, 54, 47, 38, 49, 68, 22,  7, 78],
#        [88,  5, 33, 60, 42, 94, 15, 36, 31, 49],
#        [70, 86, 61, 51, 94, 88, 45, 13, 30, 54],
#        [71, 22, 73, 27, 17, 96, 17, 57, 34, 70],
#        [53, 49, 47, 20, 99, 65,  5, 62, 98, 11],
#        [72,  6, 52, 53,  1, 15, 59,  8, 47,  2]])

# %%
hm = sns.heatmap(data = data)
plt.show()
